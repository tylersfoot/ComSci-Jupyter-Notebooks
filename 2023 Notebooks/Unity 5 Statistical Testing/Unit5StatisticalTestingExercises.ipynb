# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Titanic Revisited: Statistical Testing

# %% [markdown]
# ## Explanation of Important Fields
# survived: 0 = No; 1 = Yes<br>
# pclass: Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)<br>
# name: Full name<br>
# sex: Sex<br>
# age: Age in years<br>
# sibSp: Number of Siblings/Spouses Aboard<br>
# parch: Number of Parents/Children Aboard<br>
# ticket: Ticket Number<br>
# fare: Passenger Fare Cost ($)<br>
# cabin: Cabin number<br>
# embarked: Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)<br>

# %% [markdown]
# Import pandas, scipy, and make matplotlib available inline

# %%
import pandas as pd
from matplotlib import pyplot as plt
import scipy as sp

# %matplotlib inline

# %% [markdown]
# Read the data file into a DataFrame called df.

# %%
df = pd.read_csv('./data/train.csv', index_col=0, encoding= 'unicode_escape')

# %% [markdown]
# Print out the first 10 lines of the dataframe.

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %% [markdown]
# ### Use a t-test or ANOVA to create a null hypothesis and assess the validity of the following hypotheses. Do not assume equal variances between the groups. Supplement your findings with a histogram or groupby calculation to determine whether your hypothesis test results make sense.

# %% [markdown]
# Hypothesis: There is no difference in survival rates between passenger classes.

# %%
survive1 = df[df['Pclass'] == 1]
survive2 = df[df['Pclass'] == 2]
survive3
= df[df['Pclass'] == 3]

# %% [markdown]
# Hypothesis: There is no difference in survival rates between passenger genders.

# %% [markdown]
# Hypothesis: There is no difference in survival rates between passenger ports of embarkation.

# %% [markdown]
# ## Quick Pokemon Follow-on

# %% [markdown]
# Test the following hypothesis using the same Pokemon dataset as in the lab:<br><br>
# Hypothesis: There is no difference in the "Total" stat for Pokemon with two "Types" (Type 1 and Type 2 fields both populated in the csv) versus those with one "Type" (only Type 1 field populated in the csv).
