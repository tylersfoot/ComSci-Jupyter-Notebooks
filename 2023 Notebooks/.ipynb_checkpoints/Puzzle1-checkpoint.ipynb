# %% [markdown]
# For this month's programming puzzle, we explore the MITRE Shrewsbury security code. To enter our new building, use the keypad on the front door:
# 123
# 456
# 789
# Starting in the center, follow specific instructions to determine each number of the passcode. Here are the default instructions from the keypad manufacturer:
# ULL RRDDD LURDL UUUUD
# This yields the four-digit passcode: 1985
# Of course, Brendan changed the instructions for increased security.
# You can find the new instructions here. What is the new passcode for MITRE Shrewsbury?

# %%
p1 = '...'
p2 = '...'
p3 = '...'
p4 = '...'
p5 = '...'

# %%
coor = [2, 2]
info = [p1, p2, p3, p4, p5]
for n in info:
    for i in n:
        if i == 'U':
            coor[1]+=1
        if i == 'D':
            coor[1]-=1
        if i == 'L':
            coor[0]-=1
        if i == 'R':
            coor[0]+=1
        if coor[1] > 3:
            coor[1] = 3
        if coor[1] < 1:
            coor[1] = 1
        if coor[0] > 3:
            coor[0] = 3
        if coor[0] < 1:
            coor[0] = 1
    print(f'coord: {coor}')
    

# Correct code: 19636
# Out:
# coord: [1, 3]
# coord: [3, 1]
# coord: [3, 2]
# coord: [3, 3]
# coord: [3, 2]
