# 2097927  8aGdgYhMv4U88lJv2HhEa+JNN7bmW/MByMyUZs6YyyhG2f...     #E4ABFF
# 2097928  LhCVJf+o7OZyKYlC9ylELsM0ZJY6SRLacrGmAp3Ns7UDGf...     #2450A4
# 2097929  MxNV995Mk8r8nI8M+nXGmI6wXysjEyJJ3Q4MJL339bPypY...     #FF3881
# 2097930  7Q9OU/Z9iFdJx8lqNIH49ZuKGKk3trPfpWfdvCpEeHrdPm...     #000000
# 2097931  54Zbl8O0p/toTpRmDO1L/GUgtu12HfqIYNfZ90/pT2zHPU...     #811E9F
# 2097932  Z9lTBf4ZThRHECRjZP/lh3aqYHExrjBbwaDh1N4KsY/YFS...     #FFFFFF
# 2097933  SbRstGk3ab6StraiWBFXEGs66zLzbjz94GzCQpgAX7uWtz...     #811E9F
# 2097934  Iy4OzYmLpUKKl+K2wsdmdj8OwvUzcoyP+pcOdFX5GZnj9b...     #811E9F
# 2097935  qAtvE7qdR+oNFvuXyeDOvpFiydgxV7lmG7tQ+pNnIJ91Wj...     #FFF8B8
# 2097936  e1XwuM7/pg4RKWzh0eg/pDUmSMCgSn4vANH5glNz2+3HPT...     #BE0039
#
#         coordinate
# 0         153,1530
# 1          516,557
# 2        1241,1115
# 3         115,1542
# 4          417,421
# 5        1751,1995
# 6         106,1528
# 7           737,72
# 8         104,1574
# 9         138,1889
# 10        110,1516
# 11         78,1904
# 12       1540,1880
# 13       1062,1091
# 14        1309,431
# 15        191,1956
# 16        141,1583
# 17        131,1479
# 18       1077,1070
# 19       1359,1341
# 20        105,1699
# 21         61,1742
# 22         29,1891
# 23       1162,1399
# 24         689,800
# 25        155,1955
# 26        140,1686
# 27         623,753
# 28        1528,426
# 29         94,1554
# ...            ...
# 2097907    51,1866
# 2097908   108,1580
# 2097909    439,412
# 2097910   156,1565
# 2097911   1457,418
# 2097912   105,1539
# 2097913  1618,1940
# 2097914  1102,1243
# 2097915   1180,133
# 2097916   138,1687
# 2097917     51,857
# 2097918  1036,1861
# 2097919    64,1812
# 2097920   108,1551
# 2097921    95,1526
# 2097922  1093,1954
# 2097923     72,906
# 2097924    98,1719
# 2097925    95,1924
# 2097926   144,1508
# 2097927     894,26
# 2097928    169,199
# 2097929   150,1750
# 2097930    108,821
# 2097931    97,1557
# 2097932   165,1595
# 2097933   101,1589
# 2097934   109,1546
# 2097935   137,1667
# 2097936   674,1700
#
# [2097937 rows x 4 columns]

# %%
# fixes coordinates
def split_coords(row):
    # converts a coordinate (34, 21) into two integers, 34 and 21
    x = row[:row.find(',')]
    y = row[row.find(',')+1:]
    if y != y[:row.find(',')+2]:
        y = y[:row.find(',')]
    return {'x' : int(x), 'y' : int(y)}

dftemp = df["coordinate"].apply(lambda x: split_coords(x)) # temporary dataframe to store x and y values
dftemp = pd.DataFrame(list(dftemp))
df = pd.concat([df, dftemp], axis=1, ignore_index=True) # merges the temporary dataframe with the main dataframe
df = df.set_axis(['time', 'user', 'color', 'coordinate', 'x', 'y'], axis=1, inplace=False) # renames columns
df.head(20)
# Out:
#                            time  \
# 0   2022-04-04 22:07:15.659 UTC
# 1   2022-04-04 22:07:15.659 UTC
# 2   2022-04-04 22:07:15.659 UTC
#
#        x     y
# 0    153  1530
# 1    516   557
# 2   1241  1115
# 3    115  1542
# 4    417   421
# 5   1751  1995
# 6    106  1528
# 7    737    72
# 8    104  1574
# 9    138  1889
# 10   110  1516
# 11    78  1904
# 12  1540  1880
# 13  1062  1091
# 14  1309   431
# 15   191  1956
# 16   141  1583
# 17   131  1479
# 18  1077  1070
# 19  1359  1341

# %%
# converts time to unix
# 1648832400
format = "%Y-%m-%d %H:%M:%S"
def time_conversion(row):
    row = row[:row.find(':')+6]
    date_time = datetime.datetime.strptime(row, format)
    return (time.mktime(date_time.timetuple()) - 1648832400) # converts to unix and subtracts starting time

dftemp = df["time"].apply(lambda x: time_conversion(x)) # temporary dataframe to store unix values
dftemp = pd.DataFrame(list(dftemp))
df = pd.concat([df, dftemp], axis=1, ignore_index=True) # merges the temporary dataframe with the main dataframe
df = df.drop([0, 3], axis=1)
df = df.set_axis(['user', 'color', 'x', 'y', 'time'], axis=1, inplace=False) # renames columns
df.head(20)
# Out:
#                                                  user    color     x     y  \
# 0   covxOgrupkjMYooKc1lDddMa8hWksrZZHeAzSt3Q5sLxRv...  #811E9F   153  1530
# 1   gWChKjRd2NtGIY8pZ+1/kVIY6pwrawjy+H86G4XzE9UwqC...  #7EED56   516   557
# 2   TZL8UPxvMPD4CsTqGjykDZae2XTVS5GiUIp+jyNIurYDO3...  #DE107F  1241  1115
# 3   E8vdRDgp0LVGMUGSk/NL9jPz1YacyuS9cC/bi1QIh/fms5...  #FFFFFF   115  1542
# 4   cDfaFqIyodCCnZG7+RQzA/NFMmmiayfQ7IYo5h5o5PEbsO...  #D4D7D9   417   421
# 5   TEckQeCa6OEdyPVH69ah9U7jMirVgClZ4+mihSLQJeuBaO...  #811E9F  1751  1995
# 6   S07lKD5HuoxYr3g/moc+YeVroTtOIb6wW8BKczvnXzaM+Y...  #FFFFFF   106  1528
# 7   4ZYlysueHs4/Ry5yoeDVmbBsXF4hvHCCLDZ+WkF42Dw0Vy...  #FFFFFF   737    72
# 8   vUDqwR9Dk20AGIhHF3tAUKdGRKVDIdqUwshVCZ1G9DH4sf...  #811E9F   104  1574
# 9   82++TspbolMPu9Pp6Js2gyd9kuwZxIQG5tRc5TwvPSmzwL...  #6D482F   138  1889
# 10  IuzHRStQJhH8elCCT/PnePizop5daWk/QfUW8prb0R7QoO...  #811E9F   110  1516
# 11  KNdgQlJM8zy6sKA+vWk4hpiGtDjXPYc8wGnEseldftM5ns...  #FFB470    78  1904
# 12  W+I+Scp/wrAEMCSkmAAELPezTt7XAKdw2HoHmUObMtd1al...  #FFFFFF  1540  1880
# 13  HCDj93KkELYQ1oXQpiDWBMGUC1O5Zd6yXkk7Hn+xjZq1KW...  #000000  1062  1091
# 14  EYZdg0tFUh74ChnsyiS9mzFkllORkPLT2IzUla9v/D+dSr...  #FFFFFF  1309   431
# 15  9eXhj+QR8hq6laHd1X9bHl7vVfu0qS8Uy2OhOPTv5DQlbS...  #FFA800   191  1956
# 16  IiVLIqRd/apQPwWWOdG8dKi+s2xFa6Tztz0haCJxgPdE5i...  #811E9F   141  1583
# 17  raphlYqkIZETKcoqiQsOv3XCHFxpNkcqWm408i7NZB/yb/...  #FFFFFF   131  1479
# 18  RsZ4qzPQ1C6YItPT7dGJDbEnqXsugBRtYRGNoZ1xIPI0BV...  #BE0039  1077  1070
# 19  kfGMxu+4TILcK8NM1JCIcfpBjmp0oe/XBBoUGZPI6GOcgj...  #FFFFFF  1359  1341
#
#         time
# 0   292035.0
# 1   292035.0
# 2   292035.0
# 3   292035.0
# 4   292035.0
# 5   292035.0
# 6   292035.0
# 7   292035.0
# 8   292035.0
# 9   292035.0
# 10  292035.0
# 11  292035.0
# 12  292035.0
# 13  292035.0
# 14  292035.0
# 15  292035.0
# 16  292035.0
# 17  292035.0
# 18  292035.0
# 19  292035.0

# %%
dfTime = df[['time', 'color']].groupby('time').count()
dfTime.reset_index(inplace=True)
dfTime = dfTime.set_axis(['time', 'count'], axis=1, inplace=False) # renames columns
dfTime = dfTime.sort_values(by='count', ascending=False) # sorts by count highest to lowest
dfTime.head(5)
# Out:
#          time  count
# 293  292328.0   4330
# 292  292327.0   4277
# 294  292329.0   3791
# 291  292326.0   3423
# 295  292330.0   3370

# %%
plt.style.use('seaborn-dark')
sns.set(rc={'axes.facecolor':'lightgray', 'figure.facecolor':'lightgray'}) # sets background colors
fig, ax = plt.subplots(figsize=(15, 10))
timeGraph = sns.lineplot(data=dfTime, x='time', y='count', ci=0.9, ax=ax)
# plt.title('Number of Pixels Placed per Color', fontsize=20)
# plt.xlabel('Count', fontsize=20)
# plt.ylabel('Color', fontsize=20)
plt.show()

# %%
dfColors = df[['color','user']].groupby('color').count() # dataframe with each color and its count
dfColors.reset_index(inplace=True)
dfColors = dfColors.set_axis(['color', 'count'], axis=1, inplace=False) # renames columns
dfColors = dfColors.sort_values(by='count', ascending=False) # sorts by count highest to lowest
dfColors.head(5)

# %%
countList = dfColors['count'].tolist()
clrs = ['grey' if (x < max(countList)) else 'red' for x in countList]
for i in range(len(clrs)):
    clrs[i] = dfColors['color'].iloc[i] # sets each bar color to its respective hex value
plt.style.use('seaborn-dark')
sns.set(rc={'axes.facecolor':'lightgray', 'figure.facecolor':'lightgray'}) # sets background colors
fig, ax = plt.subplots(figsize=(15, 10))
colorsBar = sns.barplot(data=dfColors, x='count', y='color', ci=0.9, ax=ax, palette=clrs, edgecolor='black', linewidth=0)
plt.title('Number of Pixels Placed per Color', fontsize=20)
plt.xlabel('Count', fontsize=20)
plt.ylabel('Color', fontsize=20)
plt.show()

# %%
dfUsers = df[['user','color']].groupby('user').count() # dataframe with each user and their # of pixels placed
dfUsers.reset_index(inplace=True)
dfUsers = dfUsers.set_axis(['user', 'count'], axis=1, inplace=False) # renames columns
dfUsers = dfUsers.sort_values(by='count', ascending=False) # sorts by count highest to lowest
dfUsers.head(5)

# %%
plt.style.use('seaborn-dark')
sns.set(rc={'axes.facecolor':'lightgray', 'figure.facecolor':'lightgray'}) # sets background colors
fig, ax = plt.subplots(figsize=(15, 10))
usersBar = sns.lineplot(data=dfUsers, x='user', y='count', ci=0.9, ax=ax)
plt.title('Number of Pixels Placed per User', fontsize=20)
plt.xlabel('User', fontsize=20)
plt.ylabel('Count', fontsize=20)
usersBar.set(xticklabels=[])
plt.show()
