# %% [markdown]
# # Python Pandas Lab - Video Game Sales
#
# ![image.png](attachment:image.png)

# %% [markdown]
# This dataset contains a list of video games with sales, critic and users score.
#
# There are 55,792 records in the dataset as of April 12th, 2019. It was generated by a scrape of vgchartz.com.
#
# Fields include:
#
# - Rank - Ranking of overall sales
# - Name - Name of the game
# - Platform - Platform of the game (i.e. PC, PS4, XOne, etc.)
# - Genre - Genre of the game
# - ESRB Rating - ESRB Rating of the game
# - Publisher - Publisher of the game
# - Developer - Developer of the game
# - Critic Score - Critic score of the game from 10
# - User Score - Users score the game from 10
# - Total Shipped - Total shipped copies of the game
# - Global_Sales - Total worldwide sales (in millions)
# - NA_Sales - Sales in North America (in millions)
# - PAL_Sales - Sales in Europe (in millions)
# - JP_Sales - Sales in Japan (in millions)
# - Other_Sales - Sales in the rest of the world (in millions)
# - Year - Year of release of the game

# %% [markdown]
# Import pandas and read the dataset into a DataFrame called games.

# %%
import pandas as pd
games = pd.read_csv('./data/Video Game Sales.csv', sep=',')

# %% [markdown]
# Use the head command to see the first 10 rows of the dataset.

# %%
games.head(10)
# Out:
#    Rank                                Name                      basename  \
# 0     1                          Wii Sports                    wii-sports
# 1     2                   Super Mario Bros.              super-mario-bros
# 2     3                      Mario Kart Wii                mario-kart-wii
# 3     4       PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5                   Wii Sports Resort             wii-sports-resort
# 5     6  Pokemon Red / Green / Blue Version                    pokmon-red
# 6     7               New Super Mario Bros.          new-super-mario-bros
# 7     8                              Tetris                        tetris
# 8     9           New Super Mario Bros. Wii      new-super-mario-bros-wii
# 9    10                           Minecraft                     minecraft
#
#           Genre ESRB_Rating Platform         Publisher              Developer  \
# ...

# %% [markdown]
# Print out a list of all the column names in the dataset.

# %%
games.columns
# Out:
# Index(['Rank', 'Name', 'basename', 'Genre', 'ESRB_Rating', 'Platform',
#        'Publisher', 'Developer', 'VGChartz_Score', 'Critic_Score',
#        'User_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Year', 'Last_Update', 'url', 'status',
#        'Vgchartzscore', 'img_url'],
#       dtype='object')

# %% [markdown]
# Drop the columns for 'basename', 'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Last_Update', 'url', 'status',
#        'VGChartz_Score', 'img_url'.
#
# This link will help you: https://stackoverflow.com/questions/13411544/delete-column-from-pandas-dataframe

# %%
games.drop(['basename', 'NA_Sales', 'PAL_Sales', 'JP_Sales', 'Other_Sales', 'Last_Update', 'url', 'status', 'VGChartz_Score', 'img_url'], axis=1, inplace=True)
games.columns
# Out:
# Index(['Rank', 'Name', 'Genre', 'ESRB_Rating', 'Platform', 'Publisher',
#        'Developer', 'Critic_Score', 'User_Score', 'Total_Shipped',
#        'Global_Sales', 'Year', 'Vgchartzscore'],
#       dtype='object')

# %% [markdown]
# Use the describe command to understand the dataset better.

# %%
games.describe()
# Out:
#                Rank  Critic_Score  User_Score  Total_Shipped  Global_Sales  \
# count  55792.000000   6536.000000  335.000000    1827.000000  19415.000000
# mean   27896.500000      7.213709    8.253433       1.887258      0.365503
# std    16105.907446      1.454079    1.401489       4.195693      0.833022
# min        1.000000      1.000000    2.000000       0.030000      0.000000
# 25%    13948.750000      6.400000    7.800000       0.200000      0.030000
# 50%    27896.500000      7.500000    8.500000       0.590000      0.120000
# 75%    41844.250000      8.300000    9.100000       1.800000      0.360000
# max    55792.000000     10.000000   10.000000      82.860000     20.320000
#
#                Year  Vgchartzscore
# count  54813.000000     799.000000
# mean    2005.659095       7.425907
# std        8.355585       1.384226
# min     1970.000000       2.600000
# 25%     2000.000000       6.800000
# 50%     2008.000000       7.800000
# 75%     2011.000000       8.500000
# ...

# %% [markdown]
# Based on the table above, what would you say about the Vgchartzscore column?

# %% [raw]
# Vgchartzscore is most likely a scoring system ranging from 2.6 to 9.6 with a mean of 7.42

# %% [markdown]
# For how many games is the Critic_Score missing in this dataset? How about User_Score? (Hint: It's a lot!)

# %%
print(games['Critic_Score'].isna().sum())
print(games['User_Score'].isna().sum())
# Out:
# 49256
# 55457

# %% [markdown]
# Find the mean Critic_Score and mean User_Score using code, then verify using the describe table above.

# %%
print(games['Critic_Score'].mean())
print(games['User_Score'].mean())
# Out:
# 7.21370869033052
# 8.253432835820895

# %% [markdown]
# How many games were released in each year that appears in this dataset?

# %%
games['Year'].value_counts()
# Out:
# 2009.0    4507
# 2010.0    3661
# 2011.0    3489
# 2008.0    2979
# 2014.0    2905
# 2007.0    2573
# 2006.0    2112
# 2005.0    1821
# 2003.0    1738
# 2002.0    1736
# 2013.0    1723
# 2015.0    1633
# 2004.0    1611
# 2000.0    1561
# 2012.0    1560
# 2001.0    1493
# 2017.0    1486
# 2018.0    1482
# 1999.0    1285
# 2016.0    1238
# 1996.0    1220
# 1994.0    1163
# 1995.0    1162
# 1998.0    1094
# 1993.0    1043
# 1997.0    1030
# 1992.0     935
# 1991.0     786
# 2019.0     729
# 1990.0     666
# 1989.0     436
# 2020.0     331
# 1983.0     300
# 1988.0     282
# 1987.0     259
# 1982.0     214
# 1986.0     146
# 1970.0     104
# 1985.0      93
# 1984.0      88
# 1978.0      48
# 1981.0      37
# 1980.0      35
# 1977.0      12
# 1979.0       5
# 1975.0       1
# 1973.0       1
# Name: Year, dtype: int64

# %% [markdown]
# Find the 10 most popular games, as measured by Total_Shipped. There's a method called n_largest that will be of use here.

# %%
games.nlargest(10, "Total_Shipped")
# Out:
#    Rank                                Name         Genre ESRB_Rating  \
# 0     1                          Wii Sports        Sports           E
# 1     2                   Super Mario Bros.      Platform         NaN
# 2     3                      Mario Kart Wii        Racing           E
# 3     4       PlayerUnknown's Battlegrounds       Shooter         NaN
# 4     5                   Wii Sports Resort        Sports           E
# 5     6  Pokemon Red / Green / Blue Version  Role-Playing           E
# 6     7               New Super Mario Bros.      Platform           E
# 7     8                              Tetris        Puzzle           E
# 8     9           New Super Mario Bros. Wii      Platform           E
# 9    10                           Minecraft          Misc         NaN
#
#   Platform         Publisher              Developer  Critic_Score  User_Score  \
# 0      Wii          Nintendo           Nintendo EAD           7.7         NaN
# ...

# %% [markdown]
# Find the average Critic_Score, grouped by ESRB Rating.

# %%
games[['ESRB_Rating','Critic_Score']].groupby('ESRB_Rating').mean()
# Out:
#              Critic_Score
# ESRB_Rating
# AO                    NaN
# E                7.108759
# E10              7.093645
# EC               8.500000
# KA                    NaN
# M                7.467536
# RP               8.020000
# T                7.237539

# %% [markdown]
# Find the average Critic_Score, grouped by Platform and then Genre. (You may have to look up how to do multiple layers of grouping!)

# %%
games[['Platform', 'Genre', 'Critic_Score']].groupby(['Platform', 'Genre']).mean()
# Out:
#                            Critic_Score
# Platform Genre
# 2600     Action                     NaN
#          Adventure                  NaN
#          Fighting                   NaN
#          Misc                       NaN
#          Platform                   NaN
#          Puzzle                     NaN
#          Racing                     NaN
#          Role-Playing               NaN
#          Shooter                    NaN
#          Simulation                 NaN
#          Sports                     NaN
#          Strategy                   NaN
# 3DO      Action                     NaN
#          Adventure                  NaN
#          Fighting                   NaN
#          Misc                       NaN
#          Platform                   NaN
#          Puzzle                     NaN
#          Racing                     NaN
#          Role-Playing               NaN
#          Shooter                    NaN
#          Simulation                 NaN
# ...

# %% [markdown]
# Plot the ten most common platforms (measured by appearances in Platform column) as a bar graph.

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
games['Platform'].value_counts()[:10].plot(kind='bar', figsize=(15,10), )

# %% [markdown]
# Why do you think the PC has such a higher amount than any other platform here?

# %% [markdown]
# Pc is much more diverse and can support all kinds of games, especially ones that people make, however a console, such as XBox, only has games that are made from big companies.

# %% [markdown]
# Make a scatter plot with x as the Critic Score and y as the Total_Shipped,=.

# %%
games.plot.scatter(x='Critic_Score',y='Total_Shipped',figsize=(15,10))

# %% [markdown]
# Make the same scatter plot, but this time only for games witwh Critic_Score >= 8.

# %%
games[games['Critic_Score'] >= 8].plot.scatter(x='Critic_Score',y='Total_Shipped',figsize=(15,10))

# %% [markdown]
# Do you see a strong relationship between Total_Shipped and Critic_Score?

# %% [markdown]
# I see a small relationship between total copies shipped and the critic score - it is easier to see on the first scatterplot.

# %% [markdown]
# Let's check this out numerically. Find the correlation between each pair of quantitative values in the dataset. Hint: This takes one line of code.

# %%
games.corr()
# Out:
#                    Rank  Critic_Score  User_Score  Total_Shipped  \
# Rank           1.000000     -0.137650   -0.293034      -0.441132
# Critic_Score  -0.137650      1.000000    0.582673       0.203425
# User_Score    -0.293034      0.582673    1.000000      -0.025732
# Total_Shipped -0.441132      0.203425   -0.025732       1.000000
# Global_Sales  -0.554659      0.295941    0.241650            NaN
# Year          -0.097345      0.015670   -0.116728      -0.169701
# Vgchartzscore -0.295829      0.793747    0.581556       0.022811
#
#                Global_Sales      Year  Vgchartzscore
# Rank              -0.554659 -0.097345      -0.295829
# Critic_Score       0.295941  0.015670       0.793747
# User_Score         0.241650 -0.116728       0.581556
# Total_Shipped           NaN -0.169701       0.022811
# Global_Sales       1.000000 -0.041354       0.359925
# Year              -0.041354  1.000000      -0.327895
# Vgchartzscore      0.359925 -0.327895       1.000000

# %% [markdown]
# Which pair of variables has the strongest relationship? Does this make sense to you?

# %% [markdown]
# Vgchartzscore and Critic_Score has the strongest relationship (closest to 1). This makes sense as they are both scoring systems, and games rated high in one is most likely rated high in the other.
